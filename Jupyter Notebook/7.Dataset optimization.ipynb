# %% [markdown]
# # Program Description: Dataset Optimization (Module 7)
#
# ## Overview:
# This module focuses on screening outliers in the dataset by identifying samples that do not meet specified criteria based on structural descriptors such as coordination number (CN) and bond length (CR). The program uses statistical distribution analysis (from **Module 5**) to set acceptable ranges for CN and CR, and then filters out the samples that do not fall within these ranges.
#
# ### Key Steps:
# 1. **Label Screening**: The program allows users to define the range for CN and CR based on the statistical distribution charts created in **Module 5**. Samples outside the defined range are considered outliers.
# 2. **Method for Bond Length and Coordination Number Calculation**: The program provides six methods for calculating the bond length and coordination number (from **Module 2**). These methods include:
#    - `BrunnerNN_relative`
#    - `VoronoiNN`
#    - `JmolNN`
#    - `MinimumDistanceNN`
#    - `CrystalNN`
#    - `EconNN`
#
#    Users can select the method to use as the screening criterion using the `method` parameter.
#
# 3. **Filtering**: Samples that do not meet the defined criteria for CN and CR are identified and removed. The program stores the indices of the excluded samples and provides them in a CSV file for further review.
#
# ### Input:
# - **Input File**: The program reads the dataset located in the directory where the program is executed (typically the folder containing the `datasets`).
# - **Method Selection**: The user can specify the method used for calculating the bond length and coordination number. The `method` parameter should contain one of the following methods:
#   - `BrunnerNN_relative`
#   - `VoronoiNN`
#   - `JmolNN`
#   - `MinimumDistanceNN`
#   - `CrystalNN`
#   - `EconNN`
#
#   This method will be used to screen the samples.
#
# ### Output:
# - **Indices of Excluded Samples**: The indices of the samples that do not meet the defined criteria are saved in a CSV file:
#   - `indices_to_move_{method}.csv`
#   - The file is saved in the `datasets` folder for reference.
#
# - **Check Folder**: The program generates a `check` folder in the current directory. It copies the file types and labels corresponding to the excluded samples to this folder, allowing users to inspect which samples failed the criteria.
#
# - **Sorted Indices**: After the screening process, the indices of the excluded samples are extracted and sorted.
#
# ### Example Usage:
# 1. **Set Label Screening Ranges**: Use the statistical analysis from **Module 5** to define the acceptable ranges for CN and CR.
# 2. **Select Method for Calculation**: Choose one of the six methods to calculate CN and CR for screening (e.g., `BrunnerNN_relative`).
# 3. **Run the Program**: The program filters out the samples that do not meet the selected criteria, saves the excluded sample indices, and prepares a folder with the details of the excluded samples.

# %% [markdown]
# contacts: zhaohf@ihep.ac.cn

# %% [markdown]
# #  Import libraries

# %%
import os
import pandas as pd
import sys 
from os.path import join
import shutil
import logging

# %% [markdown]
# ##  Version Information

# %%
def get_python_version():
    return sys.version
def get_package_version(package_name):
    try:
        module = __import__(package_name)
        version = getattr(module, '__version__', None)
        if version:
            return version
        else:      
            return pkg_resources.get_distribution(package_name).version
    except (ImportError, AttributeError, pkg_resources.DistributionNotFound):
        return "Version info not found"

packages = ['pandas']
for package in packages:
    print(f"{package}: {get_package_version(package)}")
print(f"Python: {get_python_version()}")
# Out:
# pandas: 2.0.3
# Python: 3.8.15 | packaged by conda-forge | (default, Nov 22 2022, 08:46:39)
# [GCC 10.4.0]

# %% [markdown]
# # Parameter Settings for Dataset Optimization
#
# ## Input File:
# - **load_path**: Specifies the directory where the dataset is located. By default, this is the folder where the program is executed.
#
# ## Filter Label Range:
# - **Method Parameter**: Specifies the calculation method for the coordination number (CN) and bond length (CR). This will be used as the basis for filtering samples in the dataset. The following options are available:
#   - `'BrunnerNN_relative'`
#   - `'VoronoiNN'`
#   - `'JmolNN'`
#   - `'MinimumDistanceNN'`
#   - `'CrystalNN'`
#   - `'EconNN'`
#
#   Choose one of these methods to filter the dataset according to the corresponding CN and CR calculation.
#
# ### Example of Parameter Setup:
# ```python
# # Set the calculation method for filtering
# method = 'VoronoiNN'  # Choose the desired method

# %%
# Input file settings
dateset_path= "0926-datasets"
data_dir = os.path.join(dateset_path, "prepare")
# Method used for filtering labels (choose one from the list)
method = "JmolNN"
# File paths for CN and CR data based on the selected method
cn_file_path = os.path.join(data_dir, f"cn/cn_{method}.csv")
cr_file_path = os.path.join(data_dir, f"cr/cr_{method}.csv")
# Labels to be used for filtering
labels = ['cn', 'cr']
# Filtering ranges for each label
pick_dict = {
    'cn': [2, 12],
    'cr': [2.4, 3.2]
}
# Features to check for the selected samples
file_types_to_copy = ['xmu', 'chi', 'wt', 'rdf', 'norm', 'wt_pic']
# Path for saving the output features of the selected samples
output_file_path = os.path.join(dateset_path, f"{method}_check")
# Path for the log file
output_log_path = os.path.join(output_file_path, 'output_log.txt')
# Path for saving the indices of the selected samples
indices_output_file = os.path.join(dateset_path, f"indices_to_move_{method}.csv")
# Check if the data directory exists
if os.path.exists(data_dir):
    print(f"Directory '{data_dir}' exists.")
else:
    raise FileNotFoundError(f"Directory '{data_dir}' does not exist.")

# Function to ensure the directory exists; creates it if it does not
def ensure_directory_exists(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)
        print(f"Directory '{directory}' created.")
    else:
        print(f"Directory '{directory}' already exists, no creation needed.")

# Ensure the output directory exists
ensure_directory_exists(output_file_path)

# Check if the CN file exists
if not os.path.exists(cn_file_path):
    raise FileNotFoundError(f"File '{cn_file_path}' does not exist. No CN data available for method '{method}'.")

# Check if the CR file exists
if not os.path.exists(cr_file_path):
    raise FileNotFoundError(f"File '{cr_file_path}' does not exist. No CR data available for method '{method}'.")

print("CN File Path:", cn_file_path)
print("CR File Path:", cr_file_path)
# Out:
# Directory '0926-datasets/prepare' exists.
# Directory '0926-datasets/JmolNN_check' created.
# CN File Path: 0926-datasets/prepare/cn/cn_JmolNN.csv
# CR File Path: 0926-datasets/prepare/cr/cr_JmolNN.csv

# %% [markdown]
# # Function settings

# %%
def ensure_directory_exists(directory):
    """Ensure the specified directory exists. Creates it if it does not."""
    if not os.path.exists(directory):
        os.makedirs(directory)
        print(f"Directory '{directory}' created.")
    else:
        print(f"Directory '{directory}' already exists.")

def get_filtered_indices_from_file(file_path, min_value, max_value):
    """Get indices of samples from a file that are outside the specified range."""
    indices_to_move = set()
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        logging.info(f"Processing file: {file_path}")
        logging.info(f"Initial rows: {len(df)}")
        print(f"Processing file: {file_path}")
        print(f"Initial rows: {len(df)}")
        # Filter out samples that are not within the specified range
        filtered_df = df[(df.iloc[:, 1] < min_value) | (df.iloc[:, 1] > max_value)]
        indices_to_move.update(filtered_df.iloc[:, 0].tolist())  # Use the sample sequence number from the first column

        logging.info(f"Filtered rows: {len(filtered_df)}")
        logging.info(f"Indices to move: {indices_to_move}")
        
        print(f"Filtered rows: {len(filtered_df)}")
        print(f"Indices to move: {indices_to_move}")
    else:
        print(f"File {file_path} does not exist.")
    return indices_to_move, len(filtered_df)

def save_indices_to_csv(indices, output_file):
    """Save the filtered indices to a CSV file."""
    df_indices = pd.DataFrame(list(indices), columns=["index"])
    df_indices.to_csv(output_file, index=False)
    print(f"Saved indices to {output_file}")

def sort_and_save_csv(file_path):
    """Sort the indices in the CSV file and save the sorted data."""
    if os.path.exists(file_path):
        data = pd.read_csv(file_path)
        data = data.sort_values(by="index")  # Sort by the 'index' column
        data.to_csv(file_path, index=False)
        print(f"Sorted and saved: {file_path}")
    else:
        print(f"File does not exist: {file_path}")

def copy_files_by_indices(data_dir, indices_to_move, output_dir, file_types):
    """Copy files corresponding to sample indices to a unified check folder."""
    ensure_directory_exists(output_dir)

    for file_type in file_types:
        source_dir = os.path.join(data_dir, file_type)

        for index in indices_to_move:
            # Copy CSV files
            source_file_csv = os.path.join(source_dir, f"{index}.csv")
            if os.path.exists(source_file_csv):
                target_file_csv = os.path.join(output_dir, f"{file_type}_{index}.csv")
                shutil.copy(source_file_csv, target_file_csv)
                print(f"Copied {source_file_csv} to {target_file_csv}")

            # Copy PNG files
            source_file_png = os.path.join(source_dir, f"{index}.png")
            if os.path.exists(source_file_png):
                target_file_png = os.path.join(output_dir, f"{file_type}_{index}.png")
                shutil.copy(source_file_png, target_file_png)
                print(f"Copied {source_file_png} to {target_file_png}")

def save_all_filtered_indices(file_path, filtered_indices, output_dir, label, method):
    """Save all filtered sample indices and their corresponding values to a new CSV file."""
    ensure_directory_exists(output_dir)
    
    # Read the original data file
    df = pd.read_csv(file_path)
    
    # Filter the data for the selected indices
    filtered_data = df[df['index'].isin(filtered_indices)]
    
    # Build the output file path
    output_file = os.path.join(output_dir, f"{label}_{method}.csv")
    
    # Save the filtered data to a CSV file
    filtered_data.to_csv(output_file, index=False)
    print(f"Saved all filtered data to: {output_file}")

# %% [markdown]
# # Main Program
#
# ## Functionality:
# - This part of the program extracts the indexes of the samples that do not meet the specified screening conditions (e.g., coordination number or bond length).
# - It then saves these indexes into a CSV file and sorts them for easier reference and analysis.

# %%
# Set up the logging configuration
logging.basicConfig(filename=output_log_path, level=logging.INFO, format='%(message)s')

# Get the filtered indices from the CN and CR files
Index_to_move_cn, count_cn = get_filtered_indices_from_file(cn_file_path, *pick_dict['cn'])
Index_to_move_cr, count_cr = get_filtered_indices_from_file(cr_file_path, *pick_dict['cr'])

# Log the filtered indices results for CN and CR
logging.info(f"Indices to move from CN: {Index_to_move_cn} (Count: {count_cn})")
logging.info(f"Indices to move from CR: {Index_to_move_cr} (Count: {count_cr})")

# Sort and save the indices to a CSV file
sort_and_save_csv(indices_output_file)

# Merge the indices to move from CN and CR
indices_to_move = Index_to_move_cn.union(Index_to_move_cr)
logging.info(f"Total indices to move: {indices_to_move} (Count: {len(indices_to_move)})")

# Save the merged indices to a CSV file
save_indices_to_csv(indices_to_move, indices_output_file)

# Log the total counts of indices to move
logging.info(f"Total indices count to move from CN: (Count: {count_cn})")
logging.info(f"Total indices count to move from CR: (Count: {count_cr})")
logging.info(f"Total indices count to move from CN and CR: (Count: {len(indices_to_move)})")

# Print the total counts of indices to move
print(f"Total indices count to move from CN: (Count: {count_cn})")
print(f"Total indices count to move from CR: (Count: {count_cr})")
print(f"Total indices count to move from CN and CR: (Count: {len(indices_to_move)})")
# Out:
# Processing file: 0926-datasets/prepare/cn/cn_JmolNN.csv
# Initial rows: 5001
# Filtered rows: 38
# Indices to move: {3200, 4097, 3460, 4232, 3465, 3982, 4495, 4751, 4627, 4757, 3606, 4246, 4760, 4385, 3495, 4266, 3244, 4012, 4524, 4404, 3766, 3895, 3898, 4415, 3410, 4577, 4833, 3947, 3436, 4205, 4589, 4207, 4718, 4719, 4211, 4212, 4340, 3195}
# Processing file: 0926-datasets/prepare/cr/cr_JmolNN.csv
# Initial rows: 5001
# Filtered rows: 13
# Indices to move: {2304, 833, 2178, 2371, 2467, 2953, 363, 2284, 2638, 2894, 1939, 1463, 2524}
# File does not exist: 0926-datasets/indices_to_move_JmolNN.csv
# Saved indices to 0926-datasets/indices_to_move_JmolNN.csv
# Total indices count to move from CN: (Count: 38)
# Total indices count to move from CR: (Count: 13)
# Total indices count to move from CN and CR: (Count: 51)

# %%
# Copy files based on the selected indices to the specified output directory
copy_files_by_indices(data_dir, indices_to_move, output_file_path, file_types_to_copy)

# Process each label to save the filtered indices data
for label in labels:
    # Construct the file path for the CSV file specific to the label and method
    file_path = os.path.join(data_dir, f"{label}/{label}_{method}.csv")
    
    # Save the filtered indices and their corresponding data to a new CSV file
    save_all_filtered_indices(file_path, indices_to_move, output_file_path, label, method)
# Out:
# Directory '0926-datasets/JmolNN_check' already exists.
# Copied 0926-datasets/prepare/xmu/3200.csv to 0926-datasets/JmolNN_check/xmu_3200.csv
# Copied 0926-datasets/prepare/xmu/4097.csv to 0926-datasets/JmolNN_check/xmu_4097.csv
# Copied 0926-datasets/prepare/xmu/2304.csv to 0926-datasets/JmolNN_check/xmu_2304.csv
# Copied 0926-datasets/prepare/xmu/2178.csv to 0926-datasets/JmolNN_check/xmu_2178.csv
# Copied 0926-datasets/prepare/xmu/3460.csv to 0926-datasets/JmolNN_check/xmu_3460.csv
# Copied 0926-datasets/prepare/xmu/4232.csv to 0926-datasets/JmolNN_check/xmu_4232.csv
# Copied 0926-datasets/prepare/xmu/3465.csv to 0926-datasets/JmolNN_check/xmu_3465.csv
# Copied 0926-datasets/prepare/xmu/2953.csv to 0926-datasets/JmolNN_check/xmu_2953.csv
# Copied 0926-datasets/prepare/xmu/3982.csv to 0926-datasets/JmolNN_check/xmu_3982.csv
# Copied 0926-datasets/prepare/xmu/4495.csv to 0926-datasets/JmolNN_check/xmu_4495.csv
# Copied 0926-datasets/prepare/xmu/4751.csv to 0926-datasets/JmolNN_check/xmu_4751.csv
# Copied 0926-datasets/prepare/xmu/4627.csv to 0926-datasets/JmolNN_check/xmu_4627.csv
# Copied 0926-datasets/prepare/xmu/1939.csv to 0926-datasets/JmolNN_check/xmu_1939.csv
# Copied 0926-datasets/prepare/xmu/4757.csv to 0926-datasets/JmolNN_check/xmu_4757.csv
# Copied 0926-datasets/prepare/xmu/3606.csv to 0926-datasets/JmolNN_check/xmu_3606.csv
# Copied 0926-datasets/prepare/xmu/4246.csv to 0926-datasets/JmolNN_check/xmu_4246.csv
# Copied 0926-datasets/prepare/xmu/4760.csv to 0926-datasets/JmolNN_check/xmu_4760.csv
# Copied 0926-datasets/prepare/xmu/4385.csv to 0926-datasets/JmolNN_check/xmu_4385.csv
# Copied 0926-datasets/prepare/xmu/2467.csv to 0926-datasets/JmolNN_check/xmu_2467.csv
# Copied 0926-datasets/prepare/xmu/3495.csv to 0926-datasets/JmolNN_check/xmu_3495.csv
# Copied 0926-datasets/prepare/xmu/4266.csv to 0926-datasets/JmolNN_check/xmu_4266.csv
# Copied 0926-datasets/prepare/xmu/3244.csv to 0926-datasets/JmolNN_check/xmu_3244.csv
# Copied 0926-datasets/prepare/xmu/4012.csv to 0926-datasets/JmolNN_check/xmu_4012.csv
# Copied 0926-datasets/prepare/xmu/4524.csv to 0926-datasets/JmolNN_check/xmu_4524.csv
# Copied 0926-datasets/prepare/xmu/4404.csv to 0926-datasets/JmolNN_check/xmu_4404.csv
# Copied 0926-datasets/prepare/xmu/3766.csv to 0926-datasets/JmolNN_check/xmu_3766.csv
# Copied 0926-datasets/prepare/xmu/3895.csv to 0926-datasets/JmolNN_check/xmu_3895.csv
# Copied 0926-datasets/prepare/xmu/1463.csv to 0926-datasets/JmolNN_check/xmu_1463.csv
# Copied 0926-datasets/prepare/xmu/3898.csv to 0926-datasets/JmolNN_check/xmu_3898.csv
# Copied 0926-datasets/prepare/xmu/4415.csv to 0926-datasets/JmolNN_check/xmu_4415.csv
# Copied 0926-datasets/prepare/xmu/833.csv to 0926-datasets/JmolNN_check/xmu_833.csv
# Copied 0926-datasets/prepare/xmu/2371.csv to 0926-datasets/JmolNN_check/xmu_2371.csv
# Copied 0926-datasets/prepare/xmu/2638.csv to 0926-datasets/JmolNN_check/xmu_2638.csv
# Copied 0926-datasets/prepare/xmu/2894.csv to 0926-datasets/JmolNN_check/xmu_2894.csv
# Copied 0926-datasets/prepare/xmu/3410.csv to 0926-datasets/JmolNN_check/xmu_3410.csv
# Copied 0926-datasets/prepare/xmu/2524.csv to 0926-datasets/JmolNN_check/xmu_2524.csv
# Copied 0926-datasets/prepare/xmu/4577.csv to 0926-datasets/JmolNN_check/xmu_4577.csv
# Copied 0926-datasets/prepare/xmu/4833.csv to 0926-datasets/JmolNN_check/xmu_4833.csv
# Copied 0926-datasets/prepare/xmu/2284.csv to 0926-datasets/JmolNN_check/xmu_2284.csv
# Copied 0926-datasets/prepare/xmu/3947.csv to 0926-datasets/JmolNN_check/xmu_3947.csv
# Copied 0926-datasets/prepare/xmu/3436.csv to 0926-datasets/JmolNN_check/xmu_3436.csv
# Copied 0926-datasets/prepare/xmu/4205.csv to 0926-datasets/JmolNN_check/xmu_4205.csv
# Copied 0926-datasets/prepare/xmu/4589.csv to 0926-datasets/JmolNN_check/xmu_4589.csv
# Copied 0926-datasets/prepare/xmu/4207.csv to 0926-datasets/JmolNN_check/xmu_4207.csv
# Copied 0926-datasets/prepare/xmu/4718.csv to 0926-datasets/JmolNN_check/xmu_4718.csv
# Copied 0926-datasets/prepare/xmu/4719.csv to 0926-datasets/JmolNN_check/xmu_4719.csv
# Copied 0926-datasets/prepare/xmu/363.csv to 0926-datasets/JmolNN_check/xmu_363.csv
# Copied 0926-datasets/prepare/xmu/4211.csv to 0926-datasets/JmolNN_check/xmu_4211.csv
# Copied 0926-datasets/prepare/xmu/4212.csv to 0926-datasets/JmolNN_check/xmu_4212.csv
# Copied 0926-datasets/prepare/xmu/4340.csv to 0926-datasets/JmolNN_check/xmu_4340.csv
# Copied 0926-datasets/prepare/xmu/3195.csv to 0926-datasets/JmolNN_check/xmu_3195.csv
# Copied 0926-datasets/prepare/chi/3200.csv to 0926-datasets/JmolNN_check/chi_3200.csv
# Copied 0926-datasets/prepare/chi/4097.csv to 0926-datasets/JmolNN_check/chi_4097.csv
# Copied 0926-datasets/prepare/chi/2304.csv to 0926-datasets/JmolNN_check/chi_2304.csv
# Copied 0926-datasets/prepare/chi/2178.csv to 0926-datasets/JmolNN_check/chi_2178.csv
# Copied 0926-datasets/prepare/chi/3460.csv to 0926-datasets/JmolNN_check/chi_3460.csv
# Copied 0926-datasets/prepare/chi/4232.csv to 0926-datasets/JmolNN_check/chi_4232.csv
# Copied 0926-datasets/prepare/chi/3465.csv to 0926-datasets/JmolNN_check/chi_3465.csv
# Copied 0926-datasets/prepare/chi/2953.csv to 0926-datasets/JmolNN_check/chi_2953.csv
# Copied 0926-datasets/prepare/chi/3982.csv to 0926-datasets/JmolNN_check/chi_3982.csv
# Copied 0926-datasets/prepare/chi/4495.csv to 0926-datasets/JmolNN_check/chi_4495.csv
# Copied 0926-datasets/prepare/chi/4751.csv to 0926-datasets/JmolNN_check/chi_4751.csv
# Copied 0926-datasets/prepare/chi/4627.csv to 0926-datasets/JmolNN_check/chi_4627.csv
# Copied 0926-datasets/prepare/chi/1939.csv to 0926-datasets/JmolNN_check/chi_1939.csv
# Copied 0926-datasets/prepare/chi/4757.csv to 0926-datasets/JmolNN_check/chi_4757.csv
# Copied 0926-datasets/prepare/chi/3606.csv to 0926-datasets/JmolNN_check/chi_3606.csv
# Copied 0926-datasets/prepare/chi/4246.csv to 0926-datasets/JmolNN_check/chi_4246.csv
# Copied 0926-datasets/prepare/chi/4760.csv to 0926-datasets/JmolNN_check/chi_4760.csv
# Copied 0926-datasets/prepare/chi/4385.csv to 0926-datasets/JmolNN_check/chi_4385.csv
# Copied 0926-datasets/prepare/chi/2467.csv to 0926-datasets/JmolNN_check/chi_2467.csv
# Copied 0926-datasets/prepare/chi/3495.csv to 0926-datasets/JmolNN_check/chi_3495.csv
# Copied 0926-datasets/prepare/chi/4266.csv to 0926-datasets/JmolNN_check/chi_4266.csv
# Copied 0926-datasets/prepare/chi/3244.csv to 0926-datasets/JmolNN_check/chi_3244.csv
# Copied 0926-datasets/prepare/chi/4012.csv to 0926-datasets/JmolNN_check/chi_4012.csv
# Copied 0926-datasets/prepare/chi/4524.csv to 0926-datasets/JmolNN_check/chi_4524.csv
# Copied 0926-datasets/prepare/chi/4404.csv to 0926-datasets/JmolNN_check/chi_4404.csv
# Copied 0926-datasets/prepare/chi/3766.csv to 0926-datasets/JmolNN_check/chi_3766.csv
# Copied 0926-datasets/prepare/chi/3895.csv to 0926-datasets/JmolNN_check/chi_3895.csv
# Copied 0926-datasets/prepare/chi/1463.csv to 0926-datasets/JmolNN_check/chi_1463.csv
# Copied 0926-datasets/prepare/chi/3898.csv to 0926-datasets/JmolNN_check/chi_3898.csv
# Copied 0926-datasets/prepare/chi/4415.csv to 0926-datasets/JmolNN_check/chi_4415.csv
# Copied 0926-datasets/prepare/chi/833.csv to 0926-datasets/JmolNN_check/chi_833.csv
# Copied 0926-datasets/prepare/chi/2371.csv to 0926-datasets/JmolNN_check/chi_2371.csv
# Copied 0926-datasets/prepare/chi/2638.csv to 0926-datasets/JmolNN_check/chi_2638.csv
# Copied 0926-datasets/prepare/chi/2894.csv to 0926-datasets/JmolNN_check/chi_2894.csv
# Copied 0926-datasets/prepare/chi/3410.csv to 0926-datasets/JmolNN_check/chi_3410.csv
# Copied 0926-datasets/prepare/chi/2524.csv to 0926-datasets/JmolNN_check/chi_2524.csv
# Copied 0926-datasets/prepare/chi/4577.csv to 0926-datasets/JmolNN_check/chi_4577.csv
# Copied 0926-datasets/prepare/chi/4833.csv to 0926-datasets/JmolNN_check/chi_4833.csv
# Copied 0926-datasets/prepare/chi/2284.csv to 0926-datasets/JmolNN_check/chi_2284.csv
# Copied 0926-datasets/prepare/chi/3947.csv to 0926-datasets/JmolNN_check/chi_3947.csv
# Copied 0926-datasets/prepare/chi/3436.csv to 0926-datasets/JmolNN_check/chi_3436.csv
# Copied 0926-datasets/prepare/chi/4205.csv to 0926-datasets/JmolNN_check/chi_4205.csv
# Copied 0926-datasets/prepare/chi/4589.csv to 0926-datasets/JmolNN_check/chi_4589.csv
# Copied 0926-datasets/prepare/chi/4207.csv to 0926-datasets/JmolNN_check/chi_4207.csv
# Copied 0926-datasets/prepare/chi/4718.csv to 0926-datasets/JmolNN_check/chi_4718.csv
# Copied 0926-datasets/prepare/chi/4719.csv to 0926-datasets/JmolNN_check/chi_4719.csv
# Copied 0926-datasets/prepare/chi/363.csv to 0926-datasets/JmolNN_check/chi_363.csv
# Copied 0926-datasets/prepare/chi/4211.csv to 0926-datasets/JmolNN_check/chi_4211.csv
# Copied 0926-datasets/prepare/chi/4212.csv to 0926-datasets/JmolNN_check/chi_4212.csv
# Copied 0926-datasets/prepare/chi/4340.csv to 0926-datasets/JmolNN_check/chi_4340.csv
# Copied 0926-datasets/prepare/chi/3195.csv to 0926-datasets/JmolNN_check/chi_3195.csv
# Copied 0926-datasets/prepare/rdf/3200.csv to 0926-datasets/JmolNN_check/rdf_3200.csv
# Copied 0926-datasets/prepare/rdf/4097.csv to 0926-datasets/JmolNN_check/rdf_4097.csv
# Copied 0926-datasets/prepare/rdf/2304.csv to 0926-datasets/JmolNN_check/rdf_2304.csv
# Copied 0926-datasets/prepare/rdf/2178.csv to 0926-datasets/JmolNN_check/rdf_2178.csv
# Copied 0926-datasets/prepare/rdf/3460.csv to 0926-datasets/JmolNN_check/rdf_3460.csv
# Copied 0926-datasets/prepare/rdf/4232.csv to 0926-datasets/JmolNN_check/rdf_4232.csv
# Copied 0926-datasets/prepare/rdf/3465.csv to 0926-datasets/JmolNN_check/rdf_3465.csv
# Copied 0926-datasets/prepare/rdf/2953.csv to 0926-datasets/JmolNN_check/rdf_2953.csv
# Copied 0926-datasets/prepare/rdf/3982.csv to 0926-datasets/JmolNN_check/rdf_3982.csv
# Copied 0926-datasets/prepare/rdf/4495.csv to 0926-datasets/JmolNN_check/rdf_4495.csv
# Copied 0926-datasets/prepare/rdf/4751.csv to 0926-datasets/JmolNN_check/rdf_4751.csv
# Copied 0926-datasets/prepare/rdf/4627.csv to 0926-datasets/JmolNN_check/rdf_4627.csv
# Copied 0926-datasets/prepare/rdf/1939.csv to 0926-datasets/JmolNN_check/rdf_1939.csv
# Copied 0926-datasets/prepare/rdf/4757.csv to 0926-datasets/JmolNN_check/rdf_4757.csv
# Copied 0926-datasets/prepare/rdf/3606.csv to 0926-datasets/JmolNN_check/rdf_3606.csv
# Copied 0926-datasets/prepare/rdf/4246.csv to 0926-datasets/JmolNN_check/rdf_4246.csv
# Copied 0926-datasets/prepare/rdf/4760.csv to 0926-datasets/JmolNN_check/rdf_4760.csv
# Copied 0926-datasets/prepare/rdf/4385.csv to 0926-datasets/JmolNN_check/rdf_4385.csv
# Copied 0926-datasets/prepare/rdf/2467.csv to 0926-datasets/JmolNN_check/rdf_2467.csv
# Copied 0926-datasets/prepare/rdf/3495.csv to 0926-datasets/JmolNN_check/rdf_3495.csv
# Copied 0926-datasets/prepare/rdf/4266.csv to 0926-datasets/JmolNN_check/rdf_4266.csv
# Copied 0926-datasets/prepare/rdf/3244.csv to 0926-datasets/JmolNN_check/rdf_3244.csv
# Copied 0926-datasets/prepare/rdf/4012.csv to 0926-datasets/JmolNN_check/rdf_4012.csv
# Copied 0926-datasets/prepare/rdf/4524.csv to 0926-datasets/JmolNN_check/rdf_4524.csv
# Copied 0926-datasets/prepare/rdf/4404.csv to 0926-datasets/JmolNN_check/rdf_4404.csv
# Copied 0926-datasets/prepare/rdf/3766.csv to 0926-datasets/JmolNN_check/rdf_3766.csv
# Copied 0926-datasets/prepare/rdf/3895.csv to 0926-datasets/JmolNN_check/rdf_3895.csv
# Copied 0926-datasets/prepare/rdf/1463.csv to 0926-datasets/JmolNN_check/rdf_1463.csv
# Copied 0926-datasets/prepare/rdf/3898.csv to 0926-datasets/JmolNN_check/rdf_3898.csv
# Copied 0926-datasets/prepare/rdf/4415.csv to 0926-datasets/JmolNN_check/rdf_4415.csv
# Copied 0926-datasets/prepare/rdf/833.csv to 0926-datasets/JmolNN_check/rdf_833.csv
# Copied 0926-datasets/prepare/rdf/2371.csv to 0926-datasets/JmolNN_check/rdf_2371.csv
# Copied 0926-datasets/prepare/rdf/2638.csv to 0926-datasets/JmolNN_check/rdf_2638.csv
# Copied 0926-datasets/prepare/rdf/2894.csv to 0926-datasets/JmolNN_check/rdf_2894.csv
# Copied 0926-datasets/prepare/rdf/3410.csv to 0926-datasets/JmolNN_check/rdf_3410.csv
# Copied 0926-datasets/prepare/rdf/2524.csv to 0926-datasets/JmolNN_check/rdf_2524.csv
# Copied 0926-datasets/prepare/rdf/4577.csv to 0926-datasets/JmolNN_check/rdf_4577.csv
# Copied 0926-datasets/prepare/rdf/4833.csv to 0926-datasets/JmolNN_check/rdf_4833.csv
# Copied 0926-datasets/prepare/rdf/2284.csv to 0926-datasets/JmolNN_check/rdf_2284.csv
# Copied 0926-datasets/prepare/rdf/3947.csv to 0926-datasets/JmolNN_check/rdf_3947.csv
# Copied 0926-datasets/prepare/rdf/3436.csv to 0926-datasets/JmolNN_check/rdf_3436.csv
# Copied 0926-datasets/prepare/rdf/4205.csv to 0926-datasets/JmolNN_check/rdf_4205.csv
# Copied 0926-datasets/prepare/rdf/4589.csv to 0926-datasets/JmolNN_check/rdf_4589.csv
# Copied 0926-datasets/prepare/rdf/4207.csv to 0926-datasets/JmolNN_check/rdf_4207.csv
# Copied 0926-datasets/prepare/rdf/4718.csv to 0926-datasets/JmolNN_check/rdf_4718.csv
# Copied 0926-datasets/prepare/rdf/4719.csv to 0926-datasets/JmolNN_check/rdf_4719.csv
# Copied 0926-datasets/prepare/rdf/363.csv to 0926-datasets/JmolNN_check/rdf_363.csv
# Copied 0926-datasets/prepare/rdf/4211.csv to 0926-datasets/JmolNN_check/rdf_4211.csv
# Copied 0926-datasets/prepare/rdf/4212.csv to 0926-datasets/JmolNN_check/rdf_4212.csv
# Copied 0926-datasets/prepare/rdf/4340.csv to 0926-datasets/JmolNN_check/rdf_4340.csv
# Copied 0926-datasets/prepare/rdf/3195.csv to 0926-datasets/JmolNN_check/rdf_3195.csv
# Directory '0926-datasets/JmolNN_check' already exists.
# Saved all filtered data to: 0926-datasets/JmolNN_check/cn_JmolNN.csv
# Directory '0926-datasets/JmolNN_check' already exists.
# Saved all filtered data to: 0926-datasets/JmolNN_check/cr_JmolNN.csv
