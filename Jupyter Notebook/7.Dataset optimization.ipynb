# %% [markdown]
# # Program Description: Dataset Optimization (Module 7)
#
# ## Overview:
# This module focuses on screening outliers in the dataset by identifying samples that do not meet specified criteria based on structural descriptors such as coordination number (CN) and bond length (CR). The program uses statistical distribution analysis (from **Module 5**) to set acceptable ranges for CN and CR, and then filters out the samples that do not fall within these ranges.
#
# ### Key Steps:
# 1. **Label Screening**: The program allows users to define the range for CN and CR based on the statistical distribution charts created in **Module 5**. Samples outside the defined range are considered outliers.
# 2. **Method for Bond Length and Coordination Number Calculation**: The program provides six methods for calculating the bond length and coordination number (from **Module 2**). These methods include:
#    - `BrunnerNN_relative`
#    - `VoronoiNN`
#    - `JmolNN`
#    - `MinimumDistanceNN`
#    - `CrystalNN`
#    - `EconNN`
#
#    Users can select the method to use as the screening criterion using the `method` parameter.
#
# 3. **Filtering**: Samples that do not meet the defined criteria for CN and CR are identified and removed. The program stores the indices of the excluded samples and provides them in a CSV file for further review.
#
# ### Input:
# - **Input File**: The program reads the dataset located in the directory where the program is executed (typically the folder containing the `datasets`).
# - **Method Selection**: The user can specify the method used for calculating the bond length and coordination number. The `method` parameter should contain one of the following methods:
#   - `BrunnerNN_relative`
#   - `VoronoiNN`
#   - `JmolNN`
#   - `MinimumDistanceNN`
#   - `CrystalNN`
#   - `EconNN`
#
#   This method will be used to screen the samples.
#
# ### Output:
# - **Indices of Excluded Samples**: The indices of the samples that do not meet the defined criteria are saved in a CSV file:
#   - `indices_to_move_{method}.csv`
#   - The file is saved in the `datasets` folder for reference.
#
# - **Check Folder**: The program generates a `check` folder in the current directory. It copies the file types and labels corresponding to the excluded samples to this folder, allowing users to inspect which samples failed the criteria.
#
# - **Sorted Indices**: After the screening process, the indices of the excluded samples are extracted and sorted.
#
# ### Example Usage:
# 1. **Set Label Screening Ranges**: Use the statistical analysis from **Module 5** to define the acceptable ranges for CN and CR.
# 2. **Select Method for Calculation**: Choose one of the six methods to calculate CN and CR for screening (e.g., `BrunnerNN_relative`).
# 3. **Run the Program**: The program filters out the samples that do not meet the selected criteria, saves the excluded sample indices, and prepares a folder with the details of the excluded samples.

# %% [markdown]
# contacts: zhaohf@ihep.ac.cn

# %% [markdown]
# #  Import libraries

# %%
import os
import pandas as pd
import sys 
from os.path import join
import shutil
import logging

# %% [markdown]
# #  Version Information

# %%
def get_python_version():
    return sys.version
def get_package_version(package_name):
    try:
        module = __import__(package_name)
        version = getattr(module, '__version__', None)
        if version:
            return version
        else:      
            return pkg_resources.get_distribution(package_name).version
    except (ImportError, AttributeError, pkg_resources.DistributionNotFound):
        return "Version info not found"

packages = ['pandas']
for package in packages:
    print(f"{package}: {get_package_version(package)}")
print(f"Python: {get_python_version()}")
# Out:
# pandas: 2.0.3
# Python: 3.8.15 | packaged by conda-forge | (default, Nov 22 2022, 08:46:39)
# [GCC 10.4.0]

# %% [markdown]
# # Parameter Settings for Dataset Optimization
#
# ## Input File:
# - **load_path**: Specifies the directory where the dataset is located. By default, this is the folder where the program is executed.
#
# ## Filter Label Range:
# - **Method Parameter**: Specifies the calculation method for the coordination number (CN) and bond length (CR). This will be used as the basis for filtering samples in the dataset. The following options are available:
#   - `'BrunnerNN_relative'`
#   - `'VoronoiNN'`
#   - `'JmolNN'`
#   - `'MinimumDistanceNN'`
#   - `'CrystalNN'`
#   - `'EconNN'`
#
#   Choose one of these methods to filter the dataset according to the corresponding CN and CR calculation.
#
# ### Example of Parameter Setup:
# ```python
# # Set the calculation method for filtering
# method = 'VoronoiNN'  # Choose the desired method

# %%
# Input file settings
data_dir = "/media/dell-hd/data1/datasets/Au-datasets"
# Method used for filtering labels (choose one from the list)
method = "JmolNN"
# File paths for CN and CR data based on the selected method
cn_file_path = os.path.join(data_dir, f"cn/cn_{method}.csv")
cr_file_path = os.path.join(data_dir, f"cr/cr_{method}.csv")
# Labels to be used for filtering
labels = ['cn', 'cr']
# Filtering ranges for each label
pick_dict = {
    'cn': [2, 10],
    'cr': [2.6, 3.1]
}
# Features to check for the selected samples
file_types_to_copy = ['xmu', 'chi', 'wt', 'rdf', 'norm', 'wt_pic']
# Path for saving the output features of the selected samples
output_file_path = os.path.join(data_dir, f"{method}_check")
# Path for the log file
output_log_path = os.path.join(output_file_path, 'output_log.txt')
# Path for saving the indices of the selected samples
indices_output_file = os.path.join(data_dir, f"indices_to_move_{method}.csv")
# Check if the data directory exists
if os.path.exists(data_dir):
    print(f"Directory '{data_dir}' exists.")
else:
    raise FileNotFoundError(f"Directory '{data_dir}' does not exist.")

# Function to ensure the directory exists; creates it if it does not
def ensure_directory_exists(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)
        print(f"Directory '{directory}' created.")
    else:
        print(f"Directory '{directory}' already exists, no creation needed.")

# Ensure the output directory exists
ensure_directory_exists(output_file_path)

# Check if the CN file exists
if not os.path.exists(cn_file_path):
    raise FileNotFoundError(f"File '{cn_file_path}' does not exist. No CN data available for method '{method}'.")

# Check if the CR file exists
if not os.path.exists(cr_file_path):
    raise FileNotFoundError(f"File '{cr_file_path}' does not exist. No CR data available for method '{method}'.")

print("CN File Path:", cn_file_path)
print("CR File Path:", cr_file_path)
# Out:
# File '/media/dell-hd/data1/datasets/Au-datasets' exists.
# Directory '/media/dell-hd/data1/datasets/Au-datasets/JmolNN_check' created.
# CN File Path: /media/dell-hd/data1/datasets/Au-datasets/cn/cn_JmolNN.csv
# CR File Path: /media/dell-hd/data1/datasets/Au-datasets/cr/cr_JmolNN.csv

# %% [markdown]
# # Function settings

# %%
def ensure_directory_exists(directory):
    """Ensure the specified directory exists. Creates it if it does not."""
    if not os.path.exists(directory):
        os.makedirs(directory)
        print(f"Directory '{directory}' created.")
    else:
        print(f"Directory '{directory}' already exists.")

def get_filtered_indices_from_file(file_path, min_value, max_value):
    """Get indices of samples from a file that are outside the specified range."""
    indices_to_move = set()
    if os.path.exists(file_path):
        df = pd.read_csv(file_path)
        logging.info(f"Processing file: {file_path}")
        logging.info(f"Initial rows: {len(df)}")
        print(f"Processing file: {file_path}")
        print(f"Initial rows: {len(df)}")
        # Filter out samples that are not within the specified range
        filtered_df = df[(df.iloc[:, 1] < min_value) | (df.iloc[:, 1] > max_value)]
        indices_to_move.update(filtered_df.iloc[:, 0].tolist())  # Use the sample sequence number from the first column

        logging.info(f"Filtered rows: {len(filtered_df)}")
        logging.info(f"Indices to move: {indices_to_move}")
        
        print(f"Filtered rows: {len(filtered_df)}")
        print(f"Indices to move: {indices_to_move}")
    else:
        print(f"File {file_path} does not exist.")
    return indices_to_move, len(filtered_df)

def save_indices_to_csv(indices, output_file):
    """Save the filtered indices to a CSV file."""
    df_indices = pd.DataFrame(list(indices), columns=["index"])
    df_indices.to_csv(output_file, index=False)
    print(f"Saved indices to {output_file}")

def sort_and_save_csv(file_path):
    """Sort the indices in the CSV file and save the sorted data."""
    if os.path.exists(file_path):
        data = pd.read_csv(file_path)
        data = data.sort_values(by="index")  # Sort by the 'index' column
        data.to_csv(file_path, index=False)
        print(f"Sorted and saved: {file_path}")
    else:
        print(f"File does not exist: {file_path}")

def copy_files_by_indices(data_dir, indices_to_move, output_dir, file_types):
    """Copy files corresponding to sample indices to a unified check folder."""
    ensure_directory_exists(output_dir)

    for file_type in file_types:
        source_dir = os.path.join(data_dir, file_type)

        for index in indices_to_move:
            # Copy CSV files
            source_file_csv = os.path.join(source_dir, f"{index}.csv")
            if os.path.exists(source_file_csv):
                target_file_csv = os.path.join(output_dir, f"{file_type}_{index}.csv")
                shutil.copy(source_file_csv, target_file_csv)
                print(f"Copied {source_file_csv} to {target_file_csv}")

            # Copy PNG files
            source_file_png = os.path.join(source_dir, f"{index}.png")
            if os.path.exists(source_file_png):
                target_file_png = os.path.join(output_dir, f"{file_type}_{index}.png")
                shutil.copy(source_file_png, target_file_png)
                print(f"Copied {source_file_png} to {target_file_png}")

def save_all_filtered_indices(file_path, filtered_indices, output_dir, label, method):
    """Save all filtered sample indices and their corresponding values to a new CSV file."""
    ensure_directory_exists(output_dir)
    
    # Read the original data file
    df = pd.read_csv(file_path)
    
    # Filter the data for the selected indices
    filtered_data = df[df['index'].isin(filtered_indices)]
    
    # Build the output file path
    output_file = os.path.join(output_dir, f"{label}_{method}.csv")
    
    # Save the filtered data to a CSV file
    filtered_data.to_csv(output_file, index=False)
    print(f"Saved all filtered data to: {output_file}")

# %% [markdown]
# # Main Program: Extract Sample Indexes that Do Not Meet the Range, Save and Sort Them
#
# ## Functionality:
# - This part of the program extracts the indexes of the samples that do not meet the specified screening conditions (e.g., coordination number or bond length).
# - It then saves these indexes into a CSV file and sorts them for easier reference and analysis.

# %%
# Set up the logging configuration
logging.basicConfig(filename=output_log_path, level=logging.INFO, format='%(message)s')

# Get the filtered indices from the CN and CR files
Index_to_move_cn, count_cn = get_filtered_indices_from_file(cn_file_path, *pick_dict['cn'])
Index_to_move_cr, count_cr = get_filtered_indices_from_file(cr_file_path, *pick_dict['cr'])

# Log the filtered indices results for CN and CR
logging.info(f"Indices to move from CN: {Index_to_move_cn} (Count: {count_cn})")
logging.info(f"Indices to move from CR: {Index_to_move_cr} (Count: {count_cr})")

# Sort and save the indices to a CSV file
sort_and_save_csv(indices_output_file)

# Merge the indices to move from CN and CR
indices_to_move = Index_to_move_cn.union(Index_to_move_cr)
logging.info(f"Total indices to move: {indices_to_move} (Count: {len(indices_to_move)})")

# Save the merged indices to a CSV file
save_indices_to_csv(indices_to_move, indices_output_file)

# Log the total counts of indices to move
logging.info(f"Total indices count to move from CN: (Count: {count_cn})")
logging.info(f"Total indices count to move from CR: (Count: {count_cr})")
logging.info(f"Total indices count to move from CN and CR: (Count: {len(indices_to_move)})")

# Print the total counts of indices to move
print(f"Total indices count to move from CN: (Count: {count_cn})")
print(f"Total indices count to move from CR: (Count: {count_cr})")
print(f"Total indices count to move from CN and CR: (Count: {len(indices_to_move)})")
# Out:
# Processing file: /media/dell-hd/data1/datasets/Au-datasets/cn/cn_JmolNN.csv
# Initial rows: 5001
# Filtered rows: 17
# Indices to move: {3489, 4897, 3880, 3561, 4425, 4553, 4809, 4333, 4841, 4879, 4272, 4496, 4911, 4475, 4536, 1243, 4796}
# Processing file: /media/dell-hd/data1/datasets/Au-datasets/cr/cr_JmolNN.csv
# Initial rows: 5001
# Filtered rows: 71
# Indices to move: {4224, 2818, 4233, 4621, 3344, 3090, 4626, 4756, 4377, 4250, 4378, 4127, 1696, 3489, 3617, 4385, 4896, 4135, 3880, 4519, 4520, 4778, 4909, 4142, 4272, 4400, 3890, 4914, 3512, 4536, 4921, 3900, 4542, 4288, 4289, 4418, 4295, 4425, 4809, 4301, 3406, 3794, 4434, 4436, 1877, 3926, 4438, 3801, 4827, 3164, 3036, 4060, 4316, 4320, 3809, 4830, 3173, 4327, 4585, 4841, 3307, 4972, 4077, 2159, 2291, 4083, 2421, 3829, 4860, 3069, 4863}
# File does not exist: /media/dell-hd/data1/datasets/Au-datasets/indices_to_move_JmolNN.csv
# Saved indices to /media/dell-hd/data1/datasets/Au-datasets/indices_to_move_JmolNN.csv
# Total indices count to move from CN: (Count: 17)
# Total indices count to move from CR: (Count: 71)
# Total indices count to move from CN and CR: (Count: 81)

# %%
# Copy files based on the selected indices to the specified output directory
copy_files_by_indices(data_dir, indices_to_move, output_file_path, file_types_to_copy)

# Process each label to save the filtered indices data
for label in labels:
    # Construct the file path for the CSV file specific to the label and method
    file_path = os.path.join(data_dir, f"{label}/{label}_{method}.csv")
    
    # Save the filtered indices and their corresponding data to a new CSV file
    save_all_filtered_indices(file_path, indices_to_move, output_file_path, label, method)
# Out:
# Directory '/media/dell-hd/data1/datasets/Au-datasets/JmolNN_check' already exists.
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/2818.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_2818.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4621.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4621.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4879.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4879.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3344.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3344.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3090.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3090.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4626.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4626.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4377.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4377.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4378.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4378.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4127.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4127.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4896.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4896.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4897.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4897.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3617.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3617.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4385.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4385.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4135.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4135.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3880.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3880.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4909.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4909.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4142.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4142.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4911.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4911.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4400.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4400.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3890.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3890.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4914.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4914.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4921.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4921.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3900.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3900.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4418.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4418.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4425.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4425.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3406.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3406.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4434.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4434.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4436.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4436.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/1877.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_1877.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3926.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3926.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4438.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4438.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3164.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3164.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3173.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3173.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4972.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4972.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/2159.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_2159.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/2421.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_2421.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4475.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4475.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4224.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4224.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4233.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4233.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4496.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4496.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4756.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4756.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4250.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4250.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/1696.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_1696.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3489.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3489.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4519.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4519.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4520.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4520.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4778.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4778.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4272.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4272.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4536.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4536.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3512.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3512.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4796.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4796.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4542.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4542.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4288.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4288.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4289.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4289.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4295.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4295.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4553.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4553.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4809.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4809.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4301.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4301.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3794.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3794.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3801.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3801.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/1243.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_1243.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4827.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4827.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3036.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3036.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4060.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4060.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4316.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4316.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4320.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4320.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3809.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3809.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4830.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4830.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4327.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4327.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3561.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3561.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4841.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4841.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4585.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4585.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3307.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3307.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4333.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4333.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4077.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4077.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/2291.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_2291.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4083.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4083.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3829.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3829.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4860.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4860.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/3069.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_3069.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/xmu/4863.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/xmu_4863.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/2818.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_2818.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4621.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4621.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4879.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4879.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3344.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3344.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3090.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3090.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4626.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4626.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4377.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4377.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4378.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4378.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4127.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4127.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4896.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4896.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4897.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4897.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3617.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3617.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4385.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4385.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4135.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4135.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3880.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3880.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4909.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4909.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4142.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4142.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4911.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4911.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4400.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4400.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3890.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3890.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4914.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4914.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4921.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4921.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3900.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3900.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4418.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4418.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4425.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4425.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3406.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3406.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4434.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4434.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4436.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4436.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/1877.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_1877.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3926.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3926.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4438.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4438.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3164.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3164.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3173.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3173.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4972.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4972.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/2159.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_2159.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/2421.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_2421.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4475.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4475.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4224.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4224.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4233.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4233.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4496.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4496.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4756.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4756.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4250.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4250.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/1696.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_1696.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3489.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3489.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4519.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4519.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4520.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4520.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4778.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4778.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4272.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4272.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4536.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4536.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3512.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3512.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4796.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4796.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4542.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4542.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4288.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4288.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4289.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4289.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4295.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4295.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4553.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4553.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4809.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4809.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4301.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4301.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3794.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3794.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3801.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3801.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/1243.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_1243.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4827.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4827.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3036.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3036.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4060.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4060.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4316.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4316.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4320.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4320.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3809.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3809.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4830.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4830.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4327.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4327.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3561.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3561.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4841.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4841.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4585.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4585.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3307.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3307.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4333.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4333.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4077.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4077.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/2291.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_2291.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4083.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4083.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3829.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3829.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4860.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4860.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/3069.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_3069.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/chi/4863.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/chi_4863.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/2818.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_2818.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4621.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4621.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4879.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4879.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3344.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3344.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3090.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3090.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4626.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4626.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4377.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4377.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4378.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4378.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4127.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4127.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4896.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4896.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4897.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4897.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3617.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3617.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4385.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4385.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4135.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4135.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3880.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3880.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4909.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4909.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4142.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4142.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4911.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4911.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4400.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4400.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3890.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3890.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4914.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4914.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4921.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4921.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3900.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3900.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4418.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4418.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4425.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4425.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3406.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3406.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4434.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4434.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4436.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4436.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/1877.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_1877.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3926.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3926.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4438.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4438.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3164.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3164.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3173.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3173.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4972.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4972.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/2159.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_2159.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/2421.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_2421.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4475.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4475.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4224.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4224.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4233.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4233.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4496.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4496.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4756.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4756.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4250.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4250.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/1696.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_1696.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3489.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3489.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4519.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4519.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4520.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4520.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4778.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4778.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4272.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4272.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4536.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4536.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3512.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3512.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4796.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4796.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4542.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4542.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4288.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4288.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4289.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4289.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4295.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4295.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4553.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4553.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4809.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4809.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4301.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4301.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3794.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3794.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3801.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3801.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/1243.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_1243.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4827.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4827.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3036.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3036.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4060.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4060.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4316.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4316.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4320.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4320.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3809.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3809.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4830.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4830.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4327.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4327.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3561.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3561.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4841.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4841.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4585.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4585.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3307.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3307.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4333.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4333.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4077.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4077.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/2291.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_2291.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4083.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4083.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3829.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3829.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4860.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4860.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/3069.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_3069.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt/4863.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_4863.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/2818.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_2818.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4621.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4621.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4879.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4879.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3344.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3344.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3090.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3090.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4626.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4626.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4377.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4377.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4378.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4378.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4127.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4127.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4896.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4896.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4897.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4897.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3617.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3617.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4385.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4385.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4135.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4135.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3880.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3880.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4909.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4909.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4142.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4142.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4911.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4911.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4400.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4400.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3890.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3890.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4914.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4914.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4921.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4921.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3900.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3900.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4418.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4418.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4425.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4425.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3406.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3406.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4434.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4434.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4436.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4436.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/1877.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_1877.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3926.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3926.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4438.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4438.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3164.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3164.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3173.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3173.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4972.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4972.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/2159.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_2159.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/2421.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_2421.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4475.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4475.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4224.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4224.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4233.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4233.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4496.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4496.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4756.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4756.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4250.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4250.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/1696.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_1696.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3489.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3489.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4519.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4519.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4520.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4520.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4778.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4778.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4272.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4272.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4536.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4536.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3512.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3512.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4796.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4796.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4542.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4542.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4288.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4288.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4289.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4289.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4295.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4295.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4553.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4553.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4809.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4809.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4301.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4301.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3794.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3794.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3801.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3801.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/1243.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_1243.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4827.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4827.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3036.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3036.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4060.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4060.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4316.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4316.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4320.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4320.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3809.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3809.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4830.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4830.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4327.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4327.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3561.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3561.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4841.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4841.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4585.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4585.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3307.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3307.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4333.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4333.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4077.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4077.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/2291.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_2291.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4083.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4083.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3829.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3829.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4860.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4860.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/3069.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_3069.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/rdf/4863.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/rdf_4863.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/2818.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_2818.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4621.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4621.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4879.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4879.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3344.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3344.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3090.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3090.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4626.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4626.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4377.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4377.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4378.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4378.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4127.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4127.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4896.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4896.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4897.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4897.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3617.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3617.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4385.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4385.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4135.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4135.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3880.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3880.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4909.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4909.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4142.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4142.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4911.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4911.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4400.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4400.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3890.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3890.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4914.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4914.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4921.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4921.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3900.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3900.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4418.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4418.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4425.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4425.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3406.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3406.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4434.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4434.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4436.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4436.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/1877.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_1877.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3926.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3926.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4438.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4438.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3164.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3164.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3173.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3173.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4972.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4972.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/2159.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_2159.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/2421.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_2421.csv
# ...
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3512.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3512.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4796.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4796.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4542.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4542.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4288.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4288.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4289.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4289.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4295.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4295.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4553.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4553.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4809.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4809.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4301.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4301.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3794.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3794.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3801.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3801.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/1243.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_1243.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4827.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4827.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3036.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3036.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4060.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4060.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4316.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4316.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4320.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4320.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3809.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3809.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4830.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4830.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4327.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4327.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3561.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3561.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4841.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4841.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4585.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4585.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3307.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3307.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4333.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4333.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4077.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4077.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/2291.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_2291.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4083.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4083.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3829.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3829.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4860.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4860.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/3069.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_3069.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/norm/4863.csv to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/norm_4863.csv
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/2818.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_2818.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4621.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4621.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4879.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4879.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3344.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3344.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3090.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3090.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4626.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4626.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4377.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4377.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4378.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4378.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4127.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4127.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4896.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4896.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4897.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4897.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3617.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3617.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4385.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4385.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4135.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4135.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3880.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3880.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4909.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4909.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4142.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4142.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4911.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4911.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4400.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4400.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3890.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3890.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4914.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4914.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4921.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4921.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3900.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3900.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4418.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4418.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4425.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4425.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3406.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3406.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4434.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4434.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4436.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4436.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/1877.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_1877.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3926.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3926.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4438.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4438.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3164.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3164.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3173.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3173.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4972.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4972.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/2159.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_2159.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/2421.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_2421.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4475.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4475.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4224.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4224.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4233.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4233.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4496.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4496.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4756.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4756.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4250.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4250.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/1696.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_1696.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3489.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3489.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4519.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4519.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4520.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4520.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4778.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4778.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4272.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4272.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4536.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4536.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3512.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3512.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4796.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4796.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4542.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4542.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4288.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4288.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4289.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4289.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4295.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4295.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4553.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4553.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4809.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4809.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4301.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4301.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3794.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3794.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3801.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3801.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/1243.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_1243.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4827.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4827.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3036.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3036.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4060.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4060.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4316.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4316.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4320.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4320.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3809.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3809.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4830.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4830.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4327.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4327.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3561.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3561.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4841.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4841.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4585.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4585.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3307.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3307.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4333.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4333.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4077.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4077.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/2291.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_2291.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4083.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4083.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3829.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3829.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4860.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4860.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/3069.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_3069.png
# Copied /media/dell-hd/data1/datasets/Au-datasets/wt_pic/4863.png to /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/wt_pic_4863.png
# Directory '/media/dell-hd/data1/datasets/Au-datasets/JmolNN_check' already exists.
# Saved all filtered data to: /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/cn_JmolNN.csv
# Directory '/media/dell-hd/data1/datasets/Au-datasets/JmolNN_check' already exists.
# Saved all filtered data to: /media/dell-hd/data1/datasets/Au-datasets/JmolNN_check/cr_JmolNN.csv
